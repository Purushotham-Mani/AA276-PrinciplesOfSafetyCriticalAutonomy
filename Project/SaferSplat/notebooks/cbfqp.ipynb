# %%
# Some useful settings for interactive work
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

# %%
import sys, os
sys.path.append(os.path.abspath(".."))
import torch
from pathlib import Path
from splat.gsplat_utils import GSplatLoader
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
gs = GSplatLoader(Path("/home/purush/FiGS-Examples/gsplats/workspace/outputs/backroom/splatfacto/2025-01-19_162435/config.yml"))
x0 = torch.tensor([0.0, 0.0, 0.0], device=gs.device)
xcr = torch.tensor([0.01,0.0,0.0], device=gs.device)
# h, grad_h, hess_h, info =  gs.query_distance(x0, radius=0.1)
eps, grad_eps, hess_eps = gs.smooth_bump_epsilon(xcr, x0, 0.5)

# print(f"Distance: {h.shape}")
# print(f"Gradient: {grad_h.shape}")
# print(f"Hessian: {hess_h.shape}")
print(f"Distance: {eps}")
print(f"Gradient: {grad_eps}")
print(f"Hessian: {hess_eps}")
# Out:
# Loading latest checkpoint from load_dir
# ✅ Done loading checkpoint from outputs/backroom/splatfacto/2025-01-19_162435/nerfstudio_models/step-000029999.ckpt
# There are torch.Size([533330, 3]) Gaussians in the GSplat model
# Distance: tensor([0.3679], device='cuda:0')
# Gradient: tensor([0., 0., 0.], device='cuda:0')
# Hessian: tensor([[[2.9430, 0.0000, 0.0000],
#          [0.0000, 2.9430, 0.0000],
#          [0.0000, 0.0000, 2.9430]]], device='cuda:0')
